# %%
import pandas

# %%
import seaborn as sns

# %%
import matplotlib

# %%
data1=pandas.read_excel(r"C:\Users\HP\Downloads\Book2.xlsx")

# %%
data1.head()
# Out:
#                Name  Age  Gender   BMI  Children Smoking Status     Location  \
# 0        John Smith   35    Male  29.5         0     Non-Smoker     New York
# 1     Emily Johnson   42  Female  26.8         2     Non-Smoker  Los Angeles
# 2  Michael Williams   50    Male  31.2         3         Smoker      Chicago
# 3       Sarah Brown   28  Female  22.3         1     Non-Smoker      Houston
# 4       David Jones   39    Male  28.1         2     Non-Smoker      Phoenix
#
#    Insurance Price (USD)
# 0                  16450
# 1                  21600
# 2                  21080
# 3                  10080
# 4                  17640

# %%
y=data1[['Age']]

# %%
x=data1[['BMI']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#      BMI
# 6   25.5
# 0   29.5
# 38  31.0
# 39  29.1
# 23  25.9

# %%
x_test.head()
# Out:
#      BMI
# 8   33.0
# 15  25.1
# 25  24.5
# 41  27.8
# 14  29.8

# %%
y_train.head()
# Out:
#     Age
# 6    33
# 0    35
# 38   46
# 39   36
# 23   34

# %%
y_test.head()
# Out:
#     Age
# 8    47
# 15   32
# 25   27
# 41   38
# 14   43

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head()
# Out:
#     Age
# 8    47
# 15   32
# 25   27
# 41   38
# 14   43

# %%
y_pred[0:5]
# Out:
# array([[47.27757691],
#        [30.89281488],
#        [29.64840258],
#        [36.49267026],
#        [40.64071128]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 10.199425882836794

# %%
##multi-linear regression

# %%
data2=pandas.read_excel(r"C:\Users\HP\Downloads\Book3-linear-regression.xlsx")

# %%
data2
# Out:
#    sepal.length  sepal.width  petal.length  petal.width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
y=data2[['sepal.length']]

# %%
x=data2[["sepal.width","petal.length","petal.width"]]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr2=LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_test)

# %%
y_pred[0:5]
# Out:
# array([[5.6],
#        [6.3]])

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1.524999999999988
